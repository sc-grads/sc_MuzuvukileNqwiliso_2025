# %% [markdown]
# This is part 3

# %%
nums = [1,2,3,4,5,5]

# %%
for num in nums:
    print(num)
# Out:
# 1
# 2
# 3
# 4
# 5
# 5

# %%
i = 0
while i < 5:
    print(f"Hey {i} is less than {i+1}")
    i+=1
# Out:
# Hey 0 is less than 1
# Hey 1 is less than 2
# Hey 2 is less than 3
# Hey 3 is less than 4
# Hey 4 is less than 5

# %%
nums1 = range(1,10)

# %%
for num in nums1:
    print(f"Hey {num} is less than {num+1}")
# Out:
# Hey 1 is less than 2
# Hey 2 is less than 3
# Hey 3 is less than 4
# Hey 4 is less than 5
# Hey 5 is less than 6
# Hey 6 is less than 7
# Hey 7 is less than 8
# Hey 8 is less than 9
# Hey 9 is less than 10

# %%
list(nums1)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
x = [1,2,3,4]

# %%
y = []

# %%
for num in x:
    y.append(num**3)

# %%
[num**3 for num in x] # This is a list comprehension
# Out:
# [1, 8, 27, 64]

# %%
def hello_func(): 
    print('Hello I am a function')

# %%
hello_func()
# Out:
# Hello I am a function

# %%
def hello_method(param='Default param'):
    print(param)

# %%
hello_method('Jose')
# Out:
# Jose

# %%
hello_method()
# Out:
# Default param

# %%
def square(*args):
    """
    THIS IS A DOCUMENTATION STRINGS
    
    """
    return [num**2 for num in args]

# %%
square(2,27)
# Out:
# [4, 729]

# %%
range
