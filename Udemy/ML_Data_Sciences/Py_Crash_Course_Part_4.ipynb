# %% [markdown]
# This is a Part 4 of the crash course

# %%
sq = [3,5,6,7,2,4]

# %%
map_object = list( map(lambda num: num**2,sq)) 
"""
FOR THIS TO ACTUALLY WORK YOU WILL NEED T ONVERT THE MAP OBJECT OR WHAT EVER IS BEING RETURNED TO AN ACTUAL LIST,TUPLE, SET
"""
# Out:
# '\nFOR THIS TO ACTUALLY WORK YOU WILL NEED T ONVERT THE MAP OBJECT OR WHAT EVER IS BEING RETURNED TO AN ACTUAL LIST,TUPLE, SET\n'

# %%
numbers = map_object

# %%
numbers
# Out:
# [9, 25, 36, 49, 4, 16]

# %%
even_numbers = list(filter(lambda num : num % 2==0,numbers))

# %%
even_numbers
# Out:
# [36, 4, 16]

# %%
s = 'Hello #Sam'

# %%
s.split()
# Out:
# ['Hello', 'Sam']

# %%
s.split("#")[0]
# Out:
# 'Hello Sam'

# %%
'x' in ['x',"t",'g']
# Out:
# True

# %%
x = [(1,2),(3,4),(5,6)]

# %%
for item in x:
    print(item)
# Out:
# (1, 2)
# (3, 4)
# (5, 6)

# %%
for (a,b) in x:
    print(b)
# Out:
# 2
# 4
# 6
