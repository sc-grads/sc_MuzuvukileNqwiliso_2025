# %% [markdown]
# This is Part 2

# %%
d = {'k1':23,'k2':34}

# %%
d
# Out:
# {'k1': 23, 'k2': 34}

# %%
d['k1']
# Out:
# 23

# %%
d['k2']
# Out:
# 34

# %%
new_d = {'k1':[34,56]}

# %%
print(new_d)
# Out:
# {'k1': [34, 56]}

# %%
new_d['k1'][0]
# Out:
# 34

# %%
d = {'k1':{'innerKey':[3,6,1,89]}}

# %%
d['k1']['innerKey'][1]
# Out:
# 6

# %%
t = (2,5,67)

# %%
t[2] # The tuples are immutable
# Out:
# 67

# %%
s = {1,2,2,2,4,5,6,6,6} # This is the colllection of unique elemements there are not repeatitions

# %%
s
# Out:
# {1, 2, 4, 5, 6}

# %%
1 == 1
# Out:
# True

# %%
1 != 3
# Out:
# True

# %%
1 !=1
# Out:
# False

# %%
1 > 4
# Out:
# False

# %%
5 < 5
# Out:
# False

# %%
60 >=4
# Out:
# True

# %%
(3 < 4) and (4==6)
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True or True or False
# Out:
# True

# %%
if True :
    print('Hybo this is true')
# Out:
# Hybo this is true

# %%
if (3 > 6) and (3==5):
    print("Yep this is true")
else: 
    print("Nop this is false")
# Out:
# Nop this is false

# %%
if 1 < 2:
    print("Yaaaa!")
elif 4 > 5:
    print("Eisssh")
# Out:
# Yaaaa!
