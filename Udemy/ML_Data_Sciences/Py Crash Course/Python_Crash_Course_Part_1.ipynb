# %%
print("Hello Wolrd")
# Out:
# Hello Wolrd

# %%
"hELLO 2"
# Out:
# 'hELLO 2'

# %%
"Shift + Enter -: will print without you needing to click the run button."
# Out:
# 'Shift + Enter -: will print without you needing to click the run button.'

# %%
"Alter + Enter -: this gives a user a newline"
# Out:
# 'Alter + Enter -: this gives a user a newline'

# %% [markdown]
# isMale = True
# while isMale :
#     answer = input("Are you a male? enter Y/N");
#     if answer == "N":
#         isMale = False
#     else :
#         isMale = True
# print("The loop has ended!!!")

# %%
1 * 2.4
# Out:
# 2.4

# %%
1
# Out:
# 1

# %%
233+5
# Out:
# 238

# %%
3 **2
# Out:
# 9

# %%
(3*5+7/6.5)
# Out:
# 16.076923076923077

# %%
# String Documentation

# %%
'you can use single quotes '
# Out:
# 'you can use single quotes '

# %%
"You can use double quotes"
# Out:
# 'You can use double quotes'

# %%
name = "Angelica"

# %%
print(name)
# Out:
# Angelica

# %%
print(name + " Hello!!")
# Out:
# Angelica Hello!!

# %%
print(f"Hello {name}")
# Out:
# Hello Angelica

# %%
"Hello My name is {} ".format(name)
# Out:
# 'Hello My name is Angelica '

# %%
"Hello My name is {one} ".format(one=name)
# Out:
# 'Hello My name is Angelica '

# %%
s = "urpiuriouw"

# %%
s[0:]
# Out:
# 'urpiuriouw'

# %%
s[5:9]
# Out:
# 'riou'

# %%
s[:3]
# Out:
# 'urp'

# %%
[3,5,6,2]
# Out:
# [3, 5, 6, 2]

# %%
names = ['s4','454']
print(names)
# Out:
# ['s4', '454']

# %%
print(names[0])
# Out:
# s4

# %%
names[0] ="New Value"

# %%
print(names[0])
# Out:
# New Value

# %%
[3,56,7,[454]]
# Out:
# [3, 56, 7, [454]]

# %%
names[1][0]
# Out:
# '4'

# %%
"Hello  World"
# Out:
# 'Hello  World'

# %%
p= [[1,2,3,4,5,10],[6,7,8,9,10]]

# %%
print(p[1][2])
# Out:
# 8

# %%
print(p[0][len(p[0]) - 1])
# Out:
# 10
