# %% [markdown]
# # Reading Files
#
# Excel
# HTML
# SQL
# CSV

# %%
import pandas as pd

# %%
pd.read_excel('Excel_Sample.xlsx')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
dataFrm = pd.read_excel('Excel_Sample.xlsx')

# %%
# This will save the DataFrame to an Excel file named 'My_Output.xlsx'.
dataFrm.to_excel('My_Output.xlsx', index=False)

# %%
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
pd.read_excel("Excel_Sample.xlsx",sheet_name="Sheet1")
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15
